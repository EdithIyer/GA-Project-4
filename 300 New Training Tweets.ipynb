# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./hash_tsunami.csv')

# %%
df.head()
# Out:
#             handle                                              tweet  \
# 0     UiB_Rotevatn  . @KateClarkEqGeo @gnsscience bringing New Zea...
# 1         napakcha  How to survive a #tsunami! https://www.faceboo...
# 2  geotecniaonline  raspishake: #Indonesia is a nation of islands ...
# 3      SSkyvington  #Tsunami  Three health care tsunamis — obesity...
# 4      BerndWilke1  #Indonesia #tsunami: How a #volcano can be the...
#
#    if_tsunami             datetime  day month  year     time  if_alert_worthy
# 0        True  2019-01-15 08:07:00   15   Jan  2019  8:07 AM                0
# 1        True  2019-01-15 04:59:00   15   Jan  2019  4:59 AM                0
# 2        True  2019-01-15 06:46:00   15   Jan  2019  6:46 AM                0
# 3        True  2019-01-14 05:00:00   14   Jan  2019  5:00 AM                0
# 4        True  2019-01-15 05:48:00   15   Jan  2019  5:48 AM                0

# %%
alert_list = [529, 531, 533, 534, 555, 557, 558, 560, 563, 564, 565, 569, 573,
575, 580, 582, 584, 585, 589, 872, 891, 897, 904, 905, 908, 909, 914, 915, 919, 925, 928, 934, 936,
937, 939, 941, 943, 945, 947, 953, 955, 958, 964, 966, 967, 971, 972, 973, 976, 977]

df.ix[alert_list]['if_alert_worthy'] = 1
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """

# %%
#df.iloc[alert_list, df.columns.get_loc('if_alert_worthy')] = 1

# %%
#df_alert_worthy = df.iloc[alert_list]['if_alert_worthy']# = 1

# %%
df_alert_worthy = df.iloc[alert_list]

# %%
df.shape
# Out:
# (1416, 9)

# %%
df_alert_worthy.shape
# Out:
# (50, 9)

# %% [markdown]
# ---

# %% [markdown]
# # Drop positively labeled rows:

# %%
df.drop(index=alert_list, axis=0, inplace=True)

# %%
df.shape
# Out:
# (1366, 9)

# %%
df.head(1)
# Out:
#          handle                                              tweet  \
# 0  UiB_Rotevatn  . @KateClarkEqGeo @gnsscience bringing New Zea...
#
#    if_tsunami             datetime  day month  year     time  if_alert_worthy
# 0        True  2019-01-15 08:07:00   15   Jan  2019  8:07 AM                0

# %%
dec_23 = list(df[(df['day'] == 23) & (df['month'] == 'Dec')].index)

# %%
len(dec_23)
# Out:
# 131

# %%
df.drop(axis=0, index=dec_23, inplace=True)

# %%
df.shape
# Out:
# (1235, 9)

# %%
sep_29 = list(df[(df['day'] == 29) & (df['month'] == 'Sep')].index)

# %%
df.drop(axis=0, index=sep_29, inplace=True)

# %%
jan_2018 = list(df[(df['month'] == 'Jan') & (df['year'] == 2018)].index)

# %%
df.drop(axis=0, index=jan_2018, inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# # Randomly select 250 rows:

# %%
remaining = list(df.index)

# %%
df.head()
# Out:
#             handle                                              tweet  \
# 0     UiB_Rotevatn  . @KateClarkEqGeo @gnsscience bringing New Zea...
# 1         napakcha  How to survive a #tsunami! https://www.faceboo...
# 2  geotecniaonline  raspishake: #Indonesia is a nation of islands ...
# 3      SSkyvington  #Tsunami  Three health care tsunamis — obesity...
# 4      BerndWilke1  #Indonesia #tsunami: How a #volcano can be the...
#
#    if_tsunami             datetime  day month  year     time  if_alert_worthy
# 0        True  2019-01-15 08:07:00   15   Jan  2019  8:07 AM                0
# 1        True  2019-01-15 04:59:00   15   Jan  2019  4:59 AM                0
# 2        True  2019-01-15 06:46:00   15   Jan  2019  6:46 AM                0
# 3        True  2019-01-14 05:00:00   14   Jan  2019  5:00 AM                0
# 4        True  2019-01-15 05:48:00   15   Jan  2019  5:48 AM                0

# %%
addtl_250 = np.random.choice(remaining, 250, replace=False)

# %%
addtl_250 = list(addtl_250)

# %%
#df_alert_worthy = df.iloc[alert_list]

# %%
#df.iloc[alert_list]

# %%
#type(alert_list)

# %%
type(addtl_250[0])
# Out:
# int

# %%
addtl_250 = [int(i) for i in addtl_250]

# %%
df_addtl_250 = df.loc[addtl_250]

# %%
df_addtl_250
# Out:
#                handle                                              tweet  \
# 1097      BushraGohar  #TTPTI #NayaPakhtunkhwa Govt’s 5 years-MPAs al...
# 717           mssirsa  Look who has reached #Tsunami hit Indonesian i...
# 276          jdpmoore  The extent of the collapse at #AnakKrakatau ge...
# 535       Farhanif72_  Seventeen #Tsunami #prayforanyerpic.twitter.co...
# 13        GeoSriLanka  Dinosaurs went extinct 65 million years ago wh...
# 282   OysteinLAnderse  Indonesian authorities have said they will ins...
# 286        Federation  One week after the #Krakatoa #tsunami in Indon...
# 551   IFRCAsiaPacific  Photos just in: first aiders evacuate injured ...
# 162       doomalert19  #Tsunami #earthquake #DisasterPreaparedness Be...
# 985       IronsightEN  You need to be ready for all possibilities... ...
# 602    Strange_Sounds  Bang, Bang, Bang: M7.5, M6.0 and M6.6 earthqua...
# 722        Khalsa_Aid  Our team is in the Indonesian #Tsunami hit isl...
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Merge 50 positive with 250 negative:

# %%
df_alert_worthy.shape
# Out:
# (50, 9)

# %%
df_addtl_250.shape
# Out:
# (250, 9)

# %%
df_300 = pd.concat([df_alert_worthy, df_addtl_250])

# %%
df_300.shape
# Out:
# (300, 9)

# %%
df_300[['tweet', 'if_alert_worthy']].head(3)
# Out:
#                                                  tweet  if_alert_worthy
# 529  At least 168 killed when #tsunami hits beaches...                1
# 531  At least 43 people killed, 584 others wounded,...                1
# 533  Another disaster hitting #Indonesia bringing l...                1

# %%
df_300.to_csv('Addtnl_300_train_tweets.csv', sep=',')

# %%
df_300[['tweet', 'if_alert_worthy']].to_csv('Addtnl_300_clean.csv', sep=',', index=False)
